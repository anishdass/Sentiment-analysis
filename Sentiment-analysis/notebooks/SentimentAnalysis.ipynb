# %%
import pandas as pd
import numpy as np

# %%
train_df = pd.read_csv('train.csv')

# %%
overview_df = pd.read_csv('game_overview.csv')

# %%
train_df.head(10)
# Out:
#    review_id  ... user_suggestion
# 0          1  ...               1
# 1          2  ...               1
# 2          3  ...               1
# 3          4  ...               1
# 4          5  ...               1
# 5          6  ...               1
# 6          7  ...               1
# 7          8  ...               1
# 8          9  ...               0
# 9         10  ...               1
#
# [10 rows x 5 columns]

# %%
overview_df.head(10)
# Out:
#                               title  ...                                           overview
# 0       Spooky's Jump Scare Mansion  ...  Can you survive 1000 rooms of cute terror? Or ...
# 1                    Sakura Clicker  ...  The latest entry in the Sakura series is more ...
# 2                           WARMODE  ...  Free to play shooter about the confrontation o...
# 3                   Fractured Space  ...  Take the helm of a gigantic capital ship and g...
# 4  Counter-Strike: Global Offensive  ...  Counter-Strike: Global Offensive (CS: GO) expa...
# 5                            Dota 2  ...  The most-played game on Steam.Every day, milli...
# 6                     Path of Exile  ...  You are an Exile, struggling to survive on the...
# 7                       War Thunder  ...  War Thunder is the most comprehensive free-to-...
# 8                   Ring of Elysium  ...
# 9                   Team Fortress 2  ...  "The most fun you can have online" - PC GamerI...
#
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17494 entries, 0 to 17493
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   review_id        17494 non-null  int64
#  1   title            17494 non-null  object
#  2   year             17316 non-null  float64
#  3   user_review      17494 non-null  object
#  4   user_suggestion  17494 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 683.5+ KB

# %%
train_df[train_df.year.isnull()].title.unique()
# Out:
# array(['Fractured Space', 'Dota 2', 'Path of Exile', 'War Thunder',
#        'Ring of Elysium', 'Team Fortress 2', 'Yu-Gi-Oh! Duel Links',
#        'SMITE®', 'Brawlhalla', 'World of Tanks Blitz',
#        'DCS World Steam Edition', 'Heroes & Generals',
#        'The Elder Scrolls®: Legends™', 'Trove', 'Neverwinter',
#        'Realm Royale', 'PlanetSide 2', 'theHunter Classic',
#        'Eternal Card Game', 'Bless Online', 'RaceRoom Racing Experience',
#        'Fallout Shelter', 'Tactical Monsters Rumble Arena', 'Creativerse',
#        'Shop Heroes', 'Robocraft',
#        'Business Tour - Board Game with Online Multiplayer',
#        'AdventureQuest 3D', 'Realm Grinder', 'Bloons TD Battles',
#        'Cuisine Royale', 'EverQuest II'], dtype=object)

# %%
type(train_df.year[0])
# Out:
# numpy.float64

# %%
#Filling all the null values of year to 2015 randomly
train_df.year.fillna(np.float64(2015), inplace = True)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17494 entries, 0 to 17493
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   review_id        17494 non-null  int64
#  1   title            17494 non-null  object
#  2   year             17494 non-null  float64
#  3   user_review      17494 non-null  object
#  4   user_suggestion  17494 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 683.5+ KB

# %%
train_df.user_review[0]
# Out:
# "I'm scared and hearing creepy voices.  So I'll pause for a moment and write a review while I wait for my heart beat to return to atleast somewhat calmer times.  This game is adorable and creepy like my happy tree friends but with the graphics sceme of my childhood (but more bubble and 'clean').  Hello 1990's.What charactes there are (that isnot trying to kill me) were likable and a bit odd.  I did do a few noob things though, such as:Oh look a class room full of ghosts from dead children, lets shine my flashlight on them and stand there staring at them..Or, hmm creepy music, I'll turn around and see if I can see what's chasing me.Never before in a game have I been this afraid of finding a locked door."

# %%
#import nltk
#nltk.download('all') #This in older version is nltk.downlaod()
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from textblob import TextBlob
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# ...

# %%
#Seeing how tokenization works
temp = train_df.user_review[0]
review_words = [words for words in temp]

# %%
stop_words = set(stopwords.words('english'))

# %%
#Filtering out stop_words
filtered1 = [words for words in review_words if not words in stop_words]
filtered1
# Out:
# ['I',
#  "'",
#  ' ',
#  'c',
#  'r',
#  'e',
#  ' ',
#  'n',
#  ' ',
#  'h',
#  'e',
#  'r',
#  'n',
#  'g',
#  ' ',
#  'c',
#  'r',
#  'e',
#  'e',
#  'p',
#  ' ',
#  'v',
#  'c',
#  'e',
#  '.',
#  ' ',
#  ' ',
#  'S',
#  ' ',
#  'I',
#  "'",
#  'l',
#  'l',
#  ' ',
#  'p',
#  'u',
#  'e',
#  ' ',
#  'f',
#  'r',
#  ' ',
#  ' ',
#  'e',
#  'n',
#  ' ',
#  'n',
#  ' ',
#  'w',
#  'r',
#  'e',
#  ' ',
#  ' ',
#  'r',
#  'e',
#  'v',
#  'e',
#  'w',
#  ' ',
#  'w',
#  'h',
#  'l',
#  'e',
#  ' ',
#  'I',
#  ' ',
#  'w',
#  ' ',
#  'f',
#  'r',
#  ' ',
#  ' ',
#  'h',
#  'e',
#  'r',
#  ' ',
#  'b',
#  'e',
#  ' ',
#  ' ',
#  'r',
#  'e',
#  'u',
#  'r',
#  'n',
#  ' ',
#  ' ',
#  'l',
#  'e',
#  ' ',
#  'e',
#  'w',
#  'h',
#  ' ',
#  'c',
#  'l',
#  'e',
#  'r',
#  ' ',
#  'e',
#  '.',
#  ' ',
#  ' ',
#  'T',
#  'h',
#  ' ',
#  'g',
#  'e',
#  ' ',
#  ' ',
#  'r',
#  'b',
#  'l',
#  'e',
#  ' ',
#  'n',
#  ' ',
#  'c',
#  'r',
#  'e',
#  'e',
#  'p',
#  ' ',
#  'l',
#  'k',
#  'e',
# ...
